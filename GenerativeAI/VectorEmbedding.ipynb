# %%
# openAI not work because free version is not giving credits if you want to use either you pay for credits 
# or choose to provide your input and output data to train their model so they give free access to you api calls.

# %%
from google import genai

client = genai.Client(api_key= "")

result = client.models.embed_content(
        model="gemini-embedding-2",
        contents="What is the meaning of life?"
)

print(result.embeddings)

embedding = result.embeddings[0].values
print("Dimension:", len(embedding))
# Out:
# [ContentEmbedding(
#   values=[
#     -0.016332133,
#     -0.0043764366,
#     -0.0011324773,
#     -0.011240026,
#     0.00029597108,
#     <... 3067 more items ...>,
#   ]
# )]
# Dimension: 3072
